# %% [markdown]
# # Dataviz and -analysis of Premier League GK stat

# %% [markdown]
# ### 1. Web scrape data for Premier League GK stats
# To web scrape data from fbref.com for all goalkeeper stats

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import sys, getopt
import csv

# %%
#getting the data source
url = "https://fbref.com/en/comps/9/keepersadv/Premier-League-Stats"

# %%
def scrapeURL(url):
    res = requests.get(url)
    ## The next two lines get around the issue with comments breaking the parsing.
    comm = re.compile("<!--|-->")
    soup = BeautifulSoup(comm.sub("",res.text),'lxml')
    #all tables starts with "tbody"
    all_tables = soup.findAll("tbody")
    team_table = all_tables[0]
    player_table = all_tables[1]
    
    #parse player table
    pre_df_player = dict()
    #all the features we want from the table (found in data-stat)
    features_wanted = {"player", "nationality", "squad", "minutes_90s_gk", "goals_against", "pens_allowed", "free_kick_goals_against"
                      ,"corner_kick_goals_against", "own_goals_against", "otxg_gk", "otnpxg_per_shot_on_target_against", "otxg_net_gk"
                      , "otxg_net_per90_gk", "passes_completed_launched_gk", "passes_launched_gk", "passes_pct_launched_gk", "passes_gk"
                      , "passes_throws_gk", "pct_passes_launched_gk", "passes_length_avg_gk", "goal_kicks", "pct_goal_kicks_launched"
                      , "goal_kick_length_avg", "crosses_gk", "crosses_stopped_gk", "crosses_stopped_pct_gk", "def_actions_outside_pen_area_gk"
                      , "def_actions_outside_pen_area_per90_gk", "avg_distance_def_actions_gk"}
    
    rows_player = player_table.findAll("tr")
    for row in rows_player:
        if(row.find("th",{"scope":"row"}) != None):
            
            for f in features_wanted:
                cell = row.find("td", {"data-stat": f})
                a = cell.text.strip().encode()
                text = a.decode("utf-8")
                if f in pre_df_player:
                    pre_df_player[f].append(text)
                else:
                    pre_df_player[f] = [text]
    
    df_player = pd.DataFrame.from_dict(pre_df_player)
    return df_player

# %%
df_epl_GK = scrapeURL(url)

# %% [markdown]
# ### 2. Data analysis

# %%
#make player name index
df_epl_GK.set_index("player", inplace=True)

# %%
df_epl_GK
# Out:
#                   nationality own_goals_against passes_throws_gk goal_kicks  \
# player
# Adrián                 es ESP                 0               47         64
# Alisson                br BRA                 0               53         72
# Kepa Arrizabalaga      es ESP                 2               95        136
# Claudio Bravo          cl CHI                 0               13         28
# Martin Dúbravka        sk SVK                 1               63        196
# Ederson                br BRA                 0               88         69
# Łukasz Fabiański       pl POL                 0               35         60
# Ralf Fährmann          de GER                 0                2          3
# Ben Foster            eng ENG                 2               72        150
# Paulo Gazzaniga        ar ARG                 1               46        112
# David de Gea           es ESP                 1               93        149
# Vicente Guaita         es ESP                 1               83        154
# Angus Gunn            eng ENG                 0               24         79
# Tom Heaton            eng ENG                 1               95        196
# Dean Henderson        eng ENG                 0               58        141
# Wayne Hennessey       wal WAL                 0                4         23
# Tim Krul               nl NED                 2               95        167
# Bernd Leno             de GER                 0              132        183
# Hugo Lloris            fr FRA                 0               33         40
# David Martin          eng ENG                 0                7         32
# Alex McCarthy         eng ENG                 0               28         69
# Michael McGovern      nir NIR                 0               10         14
# Simon Moore           eng ENG                 0                2          5
# Ørjan Nyland           no NOR                 0                5         10
# Rui Patrício           pt POR                 1               70        172
# Jordan Pickford       eng ENG                 2               92        140
# Nick Pope             eng ENG                 1               86        165
# Aaron Ramsdale        eng ENG                 0              121        169
# Roberto                es ESP                 1               26         40
# Mathew Ryan            au AUS                 2              134        141
# Kasper Schmeichel      dk DEN                 0               89        148
# Jed Steer             eng ENG                 0                0          1
#
#                   pens_allowed otnpxg_per_shot_on_target_against  \
# player
# Adrián                       0                              0.30
# Alisson                      0                              0.27
# Kepa Arrizabalaga            2                              0.34
# Claudio Bravo                0                              0.30
# Martin Dúbravka              0                              0.32
# Ederson                      1                              0.36
# Łukasz Fabiański             1                              0.33
# Ralf Fährmann                1                              0.94
# Ben Foster                   5                              0.39
# Paulo Gazzaniga              3                              0.27
# David de Gea                 1                              0.29
# Vicente Guaita               0                              0.31
# Angus Gunn                   2                              0.35
# Tom Heaton                   3                              0.33
# Dean Henderson               0                              0.31
# Wayne Hennessey              0                              0.31
# Tim Krul                     2                              0.32
# Bernd Leno                   4                              0.31
# Hugo Lloris                  0                              0.29
# David Martin                 0                              0.33
# Alex McCarthy                0                              0.29
# Michael McGovern             0                              0.37
# Simon Moore                  0                              0.35
# Ørjan Nyland                 0                              0.39
# Rui Patrício                 0                              0.32
# Jordan Pickford              1                              0.36
# Nick Pope                    1                              0.29
# Aaron Ramsdale               2                              0.33
# Roberto                      1                              0.36
# Mathew Ryan                  2                              0.34
# Kasper Schmeichel            4                              0.33
# Jed Steer                    0
#
#                   free_kick_goals_against  \
# player
# Adrián                                  1
# Alisson                                 0
# Kepa Arrizabalaga                       0
# Claudio Bravo                           0
# Martin Dúbravka                         0
# Ederson                                 1
# Łukasz Fabiański                        0
# Ralf Fährmann                           0
# Ben Foster                              2
# Paulo Gazzaniga                         1
# David de Gea                            1
# Vicente Guaita                          0
# Angus Gunn                              1
# Tom Heaton                              1
# Dean Henderson                          0
# Wayne Hennessey                         0
# Tim Krul                                1
# Bernd Leno                              0
# Hugo Lloris                             0
# David Martin                            0
# Alex McCarthy                           0
# Michael McGovern                        0
# Simon Moore                             0
# Ørjan Nyland                            0
# Rui Patrício                            0
# Jordan Pickford                         3
# Nick Pope                               0
# Aaron Ramsdale                          1
# Roberto                                 1
# Mathew Ryan                             0
# Kasper Schmeichel                       0
# Jed Steer                               0
#
#                   def_actions_outside_pen_area_per90_gk  \
# player
# Adrián                                             0.57
# Alisson                                            1.15
# Kepa Arrizabalaga                                  0.76
# Claudio Bravo                                      0.26
# Martin Dúbravka                                    0.43
# Ederson                                            1.05
# Łukasz Fabiański                                   0.24
# Ralf Fährmann                                      0.00
# Ben Foster                                         0.95
# Paulo Gazzaniga                                    0.74
# David de Gea                                       0.29
# Vicente Guaita                                     0.47
# Angus Gunn                                         0.80
# Tom Heaton                                         0.40
# Dean Henderson                                     0.40
# Wayne Hennessey                                    0.00
# Tim Krul                                           0.42
# Bernd Leno                                         0.52
# Hugo Lloris                                        0.33
# David Martin                                       0.00
# Alex McCarthy                                      0.18
# Michael McGovern                                   0.57
# Simon Moore                                        0.00
# Ørjan Nyland                                       0.00
# Rui Patrício                                       0.24
# Jordan Pickford                                    0.67
# Nick Pope                                          1.29
# Aaron Ramsdale                                     0.52
# Roberto                                            0.66
# Mathew Ryan                                        0.38
# Kasper Schmeichel                                  0.62
# Jed Steer                                          0.00
#
#                   avg_distance_def_actions_gk otxg_net_per90_gk  ... otxg_gk  \
# player                                                           ...
# Adrián                                   12.5             -0.04  ...     8.6
# Alisson                                  16.2             +0.43  ...     9.8
# Kepa Arrizabalaga                        16.3             -0.27  ...    21.3
# Claudio Bravo                            12.4             -0.55  ...     4.9
# Martin Dúbravka                          12.5             +0.14  ...    35.0
# Ederson                                  19.3             -0.04  ...    16.3
# Łukasz Fabiański                         12.1             +0.48  ...    14.1
# Ralf Fährmann                             7.0             -0.49  ...     0.9
# Ben Foster                               15.1             +0.14  ...    34.9
# Paulo Gazzaniga                          14.8             -0.33  ...    16.1
# David de Gea                             13.1             -0.17  ...    20.3
# Vicente Guaita                           14.0             +0.27  ...    23.1
# Angus Gunn                               16.7             -0.96  ...    15.4
# Tom Heaton                               11.8             +0.30  ...    40.0
# Dean Henderson                           13.3             +0.21  ...    22.1
# Wayne Hennessey                          13.7             +0.04  ...     4.1
# Tim Krul                                 14.6             -0.16  ...    29.0
# Bernd Leno                               13.5             +0.01  ...    30.2
# Hugo Lloris                              11.5             +0.27  ...     9.6
# David Martin                              9.0             +0.39  ...     6.6
# Alex McCarthy                            10.2              0.00  ...    13.0
# Michael McGovern                         15.4             -1.31  ...     3.7
# Simon Moore                              14.3             -1.84  ...     1.2
# Ørjan Nyland                              7.7             -0.25  ...     1.8
# Rui Patrício                             12.2             -0.20  ...    21.8
# Jordan Pickford                          15.2             -0.13  ...    27.3
# Nick Pope                                17.3             -0.46  ...    23.3
# Aaron Ramsdale                           14.4             -0.05  ...    30.9
# Roberto                                  13.1             -0.14  ...    14.9
# Mathew Ryan                              13.5             +0.16  ...    30.3
# Kasper Schmeichel                        15.2             +0.30  ...    25.2
# Jed Steer                                                 +1.16  ...     0.1
#
#                   crosses_gk def_actions_outside_pen_area_gk goals_against  \
# player
# Adrián                    63                               5             9
# Alisson                   51                              13             5
# Kepa Arrizabalaga        107                              16            29
# Claudio Bravo             24                               1             7
# Martin Dúbravka          166                               9            33
# Ederson                   59                              18            17
# Łukasz Fabiański          55                               2            10
# Ralf Fährmann              4                               0             1
# Ben Foster               145                              20            34
# Paulo Gazzaniga          100                              11            22
# David de Gea             111                               6            25
# Vicente Guaita           115                               9            19
# Angus Gunn                62                               8            25
# Tom Heaton               156                               8            35
# Dean Henderson            99                               8            18
# Wayne Hennessey           14                               0             4
# Tim Krul                 135                               8            34
# Bernd Leno               137                              11            30
# Hugo Lloris               37                               2             8
# David Martin              27                               0             5
# Alex McCarthy             95                               2            13
# Michael McGovern          12                               1             6
# Simon Moore                0                               0             3
# Ørjan Nyland               4                               0             2
# Rui Patrício             147                               5            27
# Jordan Pickford          119                              14            32
# Nick Pope                149                              27            34
# Aaron Ramsdale           132                              11            32
# Roberto                   46                               5            17
# Mathew Ryan               84                               8            29
# Kasper Schmeichel        113                              13            19
# Jed Steer                  0                               0             0
#
#                   passes_completed_launched_gk crosses_stopped_pct_gk  \
# player
# Adrián                                      54                    6.3
# Alisson                                     59                    3.9
# Kepa Arrizabalaga                           94                    6.5
# Claudio Bravo                               19                    4.2
# Martin Dúbravka                            167                    7.8
# Ederson                                     64                   11.9
# Łukasz Fabiański                            73                    3.6
# Ralf Fährmann                                1                    0.0
# Ben Foster                                 160                    9.0
# Paulo Gazzaniga                             69                    6.0
# David de Gea                                66                    4.5
# Vicente Guaita                             125                    7.8
# Angus Gunn                                  46                    8.1
# Tom Heaton                                 129                    7.1
# Dean Henderson                             121                    8.1
# Wayne Hennessey                             22                    7.1
# Tim Krul                                   131                    7.4
# Bernd Leno                                  64                   10.2
# Hugo Lloris                                 37                   10.8
# David Martin                                35                    0.0
# Alex McCarthy                               72                    9.5
# Michael McGovern                             9                    0.0
# Simon Moore                                  3
# Ørjan Nyland                                 9                    0.0
# Rui Patrício                               142                    2.7
# Jordan Pickford                            196                    8.4
# Nick Pope                                  167                   12.8
# Aaron Ramsdale                              94                    7.6
# Roberto                                     49                    6.5
# Mathew Ryan                                135                    7.1
# Kasper Schmeichel                          130                    2.7
# Jed Steer                                    0
#
#                   crosses_stopped_gk passes_launched_gk passes_length_avg_gk  \
# player
# Adrián                             4                133                 38.5
# Alisson                            2                106                 32.3
# Kepa Arrizabalaga                  7                228                 32.4
# Claudio Bravo                      1                 47                 31.5
# Martin Dúbravka                   13                432                 48.0
# Ederson                            7                114                 29.8
# Łukasz Fabiański                   2                193                 50.2
# Ralf Fährmann                      0                  3                 29.7
# Ben Foster                        13                529                 53.9
# Paulo Gazzaniga                    6                231                 39.0
# David de Gea                       5                180                 35.0
# Vicente Guaita                     9                382                 44.9
# Angus Gunn                         5                190                 50.4
# Tom Heaton                        11                384                 45.9
# Dean Henderson                     8                478                 58.4
# Wayne Hennessey                    1                 56                 55.0
# Tim Krul                          10                389                 41.4
# Bernd Leno                        14                228                 32.3
# Hugo Lloris                        4                 72                 35.9
# David Martin                       0                 83                 57.6
# Alex McCarthy                      9                210                 50.4
# Michael McGovern                   0                 29                 38.4
# Simon Moore                        0                 19                 63.7
# Ørjan Nyland                       0                 18                 41.7
# Rui Patrício                       4                305                 42.9
# Jordan Pickford                   10                480                 49.7
# Nick Pope                         19                515                 55.1
# Aaron Ramsdale                    10                333                 41.3
# Roberto                            3                167                 49.0
# Mathew Ryan                        6                254                 31.9
# Kasper Schmeichel                  3                264                 36.6
# Jed Steer                          0                  1                 26.0
#
#                   corner_kick_goals_against
# player
# Adrián                                    1
# Alisson                                   0
# Kepa Arrizabalaga                         4
# Claudio Bravo                             0
# Martin Dúbravka                           7
# Ederson                                   2
# Łukasz Fabiański                          1
# Ralf Fährmann                             0
# Ben Foster                                3
# Paulo Gazzaniga                           2
# David de Gea                              6
# Vicente Guaita                            4
# Angus Gunn                                1
# Tom Heaton                                7
# Dean Henderson                            2
# Wayne Hennessey                           2
# Tim Krul                                  8
# Bernd Leno                                4
# Hugo Lloris                               0
# David Martin                              1
# Alex McCarthy                             3
# Michael McGovern                          0
# Simon Moore                               0
# Ørjan Nyland                              0
# Rui Patrício                              5
# Jordan Pickford                           4
# Nick Pope                                 3
# Aaron Ramsdale                            4
# Roberto                                   3
# Mathew Ryan                               4
# Kasper Schmeichel                         3
# Jed Steer                                 0
#
# [32 rows x 28 columns]
